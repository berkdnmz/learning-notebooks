# %%
from sklearn.cluster import KMeans, DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

import importnb
with importnb.Notebook():
    from myKmeans import kmeans as mykmeans
with importnb.Notebook():
    from myDBSCAN import dbscan as mydbscan

# %%
X, y = make_blobs(n_samples=1000, centers=4, cluster_std=2.4, random_state=31)
plt.scatter(X[:,0], X[:,1], c="black", s=100, alpha=1, label="Original Data")

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit_transform(X)
# Out:
# C:\Users\berkd\.conda\envs\myenv\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# array([[ 3.10007899, 18.87985192, 13.02218004, 10.13600113],
#        [19.13604958, 13.67483949,  3.15218668, 22.71819435],
#        [10.47518771, 19.0703338 , 20.94224801,  0.7958567 ],
#        ...,
#        [ 2.36264181, 23.62112673, 18.36432881, 10.05027396],
#        [ 4.42118868, 25.19561901, 20.4438328 , 10.20243662],
#        [19.69618992,  2.10312034, 12.05768207, 17.41989918]])

# %%
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c=y_kmeans, cmap="viridis", s=50)
plt.title("K-means Clustering")
plt.show()

# %%
dbscan = DBSCAN(eps=2, min_samples=4)
y_dbscan = dbscan.fit_predict(X)

# %%
(centers, y) = mykmeans(X.tolist(),4,10000)

# %%
plt.scatter(X[:,0], X[:,1], c=y_dbscan, cmap="viridis", s=50)
plt.title("MY K-means CLUSTERİNG")
plt.show()
